# %% [markdown]
# # Python-based pipeline for preprocessing of RNA-seq datasets

# %% [markdown]
# ## Protocol B-1 - Data Pre-processing for RNA-seq dataset

# %% [markdown]
# ## Step 1. Set-up
#
# ### Install and import libraries
#
# Install the packages using `pip`.
# If you want to install the library, then type  "pip3 install `package name`" in terminal.

# %%
import os, math, shutil, time, datetime, importlib

libraries = {
    'numpy': 'numpy',
    'Bio': 'biopython',
    'pysam': 'pysam',
    'pandas': 'pandas'
}

# Check and install Python libraries
for lib, package_name in libraries.items():
    try:
        importlib.import_module(lib)
        print(f"{lib} is installed.")
    except ImportError:
        print(f"{lib} is not installed. Installing {package_name}...")
        os.system(f'pip3 install {package_name}')

# Binary tools to check and install
binary_tools = ['samtools', 'bedtools', 'bowtie2']

# Check and install binary tools
for tool_name in binary_tools:
    if os.system(f'which {tool_name} > /dev/null 2>&1') == 0:
        print(f"{tool_name} is already installed.")
    else:
        print(f"{tool_name} is not installed. Installing {tool_name}...")
        os.system(f'apt-get update && apt-get install -y {tool_name}')
# Out:
# numpy is installed.
# Bio is not installed. Installing biopython...
# pysam is not installed. Installing pysam...
# pandas is installed.
# samtools is not installed. Installing samtools...
# bedtools is not installed. Installing bedtools...
# bowtie2 is not installed. Installing bowtie2...

# %%
from numpy import zeros
from Bio import SeqIO
import pandas as pd
import pysam

# %% [markdown]
# ### Function
#
# Please run the cell without modification

# %%
def count_coverage(samfile, chromosome_size=6000000, flip=True):
    """counts coverage per base in a strand-specific manner

    For paired-end reads, the insert betwen the mapped reads is
    also counted.

    flip: Whether or not the strands should be flipped.
    This should be true for RNA-seq, and false for ChIP-exo

    chromosome_size: This value should be larger than the largest chromosome"""

    if samfile.has_index():
        return count_coverage_indexed(samfile, chromosome_size=chromosome_size, flip=flip)
    all_counts = {}
    plus_strands = []
    minus_strands = []
    if "SQ" in samfile.header:
        chromosome_sizes = {}
        for entry in samfile.header["SQ"]:
            chromosome_sizes[entry["SN"]] = int(entry["LN"]) + 1
    else:
        for reference in samfile.references:
            chromosome_sizes[reference] = chromosome_size
    for reference in samfile.references:  # create an array for each reference
        plus_strands.append(zeros((chromosome_sizes[reference],)))
        minus_strands.append(zeros((chromosome_sizes[reference],)))
    # iterate through each mapped read
    for i, read in enumerate(samfile):
        if read.is_unmapped:
            continue
        if not read.is_proper_pair:
            if read.is_reverse:
                minus_strands[read.tid][read.pos:read.aend] += 1
            else:
                plus_strands[read.tid][read.pos:read.aend] += 1
        # for paired-end data, get entire insert from only read1
        elif read.is_read1:
            if read.is_reverse:
                minus_strands[read.tid][read.pnext:read.aend] += 1
            else:
                plus_strands[read.tid][read.pos:read.pos + read.isize] += 1
    # store the results per reference
    for i, reference in enumerate(samfile.references):
        all_counts[reference] = {}
        if flip:
            all_counts[reference]["-"] = plus_strands[i]
            all_counts[reference]["+"] = minus_strands[i]
        else:
            all_counts[reference]["+"] = plus_strands[i]
            all_counts[reference]["-"] = minus_strands[i]
    return all_counts

def count_coverage_indexed(samfile, chromosome_size=6000000, flip=True):
    """counts coverage per base in a strand-specific manner

    For paired-end reads, the insert betwen the mapped reads is
    also counted.

    flip: Whether or not the strands should be flipped.
    This should be true for RNA-seq, and false for ChIP-exo

    chromsome_size: This value should be larger than the largest chromosome"""
    if "SQ" in samfile.header:
        chromosome_sizes = {}
        for entry in samfile.header["SQ"]:
            chromosome_sizes[entry["SN"]] = int(entry["LN"]) + 1
    else:
        for reference in samfile.references:
            chromosome_sizes[reference] = chromosome_size
    all_counts = {}
    for reference in samfile.references:  # go through each chromosome
        plus_strand = zeros((chromosome_sizes[reference],))
        minus_strand = zeros((chromosome_sizes[reference],))
        # iterate through each mapped read
        for i, read in enumerate(samfile.fetch(reference=reference)):
            if not read.is_proper_pair:
                if read.is_reverse:
                    minus_strand[read.pos:read.aend] += 1
                else:
                    plus_strand[read.pos:read.aend] += 1
            # for paired-end data, get entire insert from only read1
            elif read.is_read1:
                if read.is_reverse:
                    minus_strand[read.pnext:read.aend] += 1
                else:
                    plus_strand[read.pos:read.pos + read.isize] += 1
            all_counts[reference] = {}
            if flip:
                all_counts[reference]["-"] = plus_strand
                all_counts[reference]["+"] = minus_strand
            else:
                all_counts[reference]["+"] = plus_strand
                all_counts[reference]["-"] = minus_strand
    return all_counts

def write_samfile_to_gff(samfile, output, chromosome_size=6000000,
                         separate_strand=True, flip=True, log_scale=True):
    """write samfile object to an output object in a gff format

    flip: Whether or not the strands should be flipped.
    This should be true for RNA-seq, and false for ChIP-exo

    chromsome_size: This value should be larger than the largest chromosome

    separate_strand: Whether the forward and reverse strands should be made
    into separate tracks (True) or the negative strand should be rendered
    as negative values (False)
    """
    all_counts = count_coverage(samfile, chromosome_size=chromosome_size,
                                flip=flip)

    name = os.path.split(samfile.filename)[1].decode()
    for reference in all_counts:
        for strand in all_counts[reference]:
            counts = all_counts[reference][strand]
            for i in counts.nonzero()[0]:
                if log_scale:
                    count = math.log(float(counts[i]), 2)
                else:
                    count = counts[i]
                if separate_strand:
                    output.write("%s\t\t%s\t%d\t%d\t%.2f\t%s\t.\t.\n" %
                        (reference, "%s_(%s)" % (name, strand), i, i,count, strand))
                else:
                    output.write("%s\t\t%s\t%d\t%d\t%.2f\t%s\t.\t.\n" %
                        (reference, name, i, i, count,strand))

def convert_samfile_to_gff(sam_filename, out_filename, chromosome_size=6000000,
                           separate_strand=True, flip=True, log_scale=True):
    """read in the a samfile from a path, and write it out to a gff filepath

    flip: Whether or not the strands should be flipped.
    This should be true for RNA-seq, and false for ChIP-exo.

    chromsome_size: This value should be larger than the largest chromosome.

    separate_strand: Whether the forward and reverse strands should be made
    into separate tracks (True) or the negative strand should be rendered
    as negative values (False)
    """
    samfile = pysam.Samfile(sam_filename)
    with open(out_filename, "w") as outfile:
        write_samfile_to_gff(samfile, outfile, chromosome_size=chromosome_size,
                             separate_strand=separate_strand, flip=flip,
                             log_scale=log_scale)
    samfile.close()

def convert_sam_to_bedgraph(sam_bam_sorted, dir_bed_output):
    bedgraph_file_positive = f"{dir_bed_output}_positive.bedgraph"
    bedgraph_file_negative = f"{dir_bed_output}_negative.bedgraph"

    # !bedtools genomecov -ibam $sam_bam_sorted -bg -strand + > $bedgraph_file_positive
    # !bedtools genomecov -ibam $sam_bam_sorted -bg -strand - > $bedgraph_file_negative

# %% [markdown]
# ### (Optional) Google Drive Mount
#
# If using Google Colab, it is necessary to mount Google Drive to access the files stored within it.

# %%
from google.colab import drive, files

drive.mount('/content/mnt')
# Out:
# Drive already mounted at /content/mnt; to attempt to forcibly remount, call drive.mount("/content/mnt", force_remount=True).

# %% [markdown]
# ### Set the working directory

# %%
working_directory =  '/content/mnt/My Drive/Test/RNA-seq'  #Enter your working directory.

os.chdir(working_directory)
print(f'Current working directiory : {os.getcwd()}')
# Out:
# Current working directiory : /content/mnt/My Drive/Test/RNA-seq

# %% [markdown]
# ## Step 2. Prepare the files
#
# Prepare the following files and move them into the working directory:
# * **GenBank_file** : Enter the GenBank file name of the reference strain.
# * **Organism** : Enter the accession number of the reference genome from the GenBank file. (e.g. *Escherichia coli* K-12 MG1655 : NC_000913.3)
# * **Sample_name_list** : Enter the names of the prepared RNA-seq files, which include both R1 and R2 for paired-end sequencing, excluding the read number and file format (e.g., `RNA_seq_sample_1_R1.fastq.gz` and `RNA_seq_sample_1_R2.fastq.gz` -> `RNA_seq_sample_1`).

# %%
GenBank_file = 'NC_000913.3.gb'
Organism = 'NC_000913.3'
Sample_name_list = ['mini_RNA-seq_Ecoli_mid-37-1',
                    'mini_RNA-seq_Ecoli_mid-37-2',
                    'mini_RNA-seq_Ecoli_del_rpoS_mid-37-1',
                    'mini_RNA-seq_Ecoli_del_rpoS_mid-37-2']

# %% [markdown]
# ### Directory setting

# %%
# !mkdir '0_raw' '1_reference' '1_reference/rRNA_index' '1_reference/reference_genome_index' '2_alignment' '2_alignment/rRNA_del_fastq' '3_result'
# !mv ./*.gb ./1_reference/
# !mv ./*.gz ./0_raw/
print(f'Make directory : Success')
# Out:
# Make directory : Success

# %% [markdown]
# ## Step 3. Generate Fasta files from the reference genome file

# %%
# Set the name of reference files.
dir_genbank_file = f'./1_reference/{GenBank_file}'
dir_genome_fasta = f'./1_reference/{Organism}.fasta'
dir_rRNA_fasta = f'./1_reference/{Organism}_rRNA.fasta'

# Make the reference genome fasta file.
with open(dir_genome_fasta, "w") as genome_fasta:
    for record in SeqIO.parse(dir_genbank_file, "genbank"):
        SeqIO.write(record, genome_fasta, "fasta")

# Make the ribosomal RNA of reference genome fasta file.
with open(dir_rRNA_fasta, "w") as rRNA_fasta:
    for record in SeqIO.parse(dir_genbank_file, "genbank"):
        for feature in record.features:
            if feature.type == "rRNA":
                rRNA_seq = feature.extract(record)
                rRNA_seq.id = Organism
                rRNA_seq.description = ""
                SeqIO.write(rRNA_seq, rRNA_fasta, "fasta")

print('Step 3 is done.')
# Out:
# Step 3 is done.

# %% [markdown]
# ## Step 4. Remove the rRNA sequences for RNA-seq dataset
#
# Unzip and align the sequencing reads file (.fastq.gz) to the rRNA sequences from reference genome using Bowtie 2 and remove the aligned rRNA reads from each sequencing read.

# %%
# Build the bowtie2 index set for removing the rRNA sequences
dir_rRNA_ref = f'./1_reference/rRNA_index/{Organism}'
# !bowtie2-build $dir_rRNA_fasta $dir_rRNA_ref

#Data pre-process
for file in Sample_name_list:
    print(f'{file} processing ...')

    raw_R1_gz = f'./0_raw/{file}_R1.fastq.gz'
    raw_R2_gz = f'./0_raw/{file}_R2.fastq.gz'

    # Unzip the fastq.gz file
    # !gunzip -k $raw_R1_gz > /dev/null
    # !gunzip -k $raw_R2_gz > /dev/null

    raw_R1_fastq = f'./0_raw/{file}_R1.fastq'
    raw_R2_fastq = f'./0_raw/{file}_R2.fastq'

    rRNA_del_fastq_gz = f'./2_alignment/rRNA_del_fastq/rRNA_del_{file}.fastq.gz'
    rRNA_mapped_sam = f'./2_alignment/rRNA_mapped_{file}.sam'

    print('\t Aligning to rRNA sequences of reference genome...')
    # !bowtie2 -x $dir_rRNA_ref -1 $raw_R1_fastq -2 $raw_R2_fastq --un-conc-gz $rRNA_del_fastq_gz -S $rRNA_mapped_sam
    # !rm $rRNA_mapped_sam

print('Step 4 is done.')
# Out:
# Settings:
#   Output files: "./1_reference/rRNA_index/NC_000913.3.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   ./1_reference/NC_000913.3_rRNA.fasta
# Building a SMALL index
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
# bmax according to bmaxDivN setting: 8020
# Using parameters --bmax 6015 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 6015 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:00
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 4009.5 (target: 6014)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 8
#   Reserving size (6015) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
#   bucket 1: 20%
#   bucket 1: 30%
#   bucket 1: 40%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 5287 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5288 for bucket 1
# Getting block 2 of 8
#   Reserving size (6015) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 5768 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5769 for bucket 2
# Getting block 3 of 8
#   Reserving size (6015) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 3072 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 3073 for bucket 3
# Getting block 4 of 8
#   Reserving size (6015) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 4251 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 4252 for bucket 4
# Getting block 5 of 8
#   Reserving size (6015) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 1943 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 1944 for bucket 5
# Getting block 6 of 8
#   Reserving size (6015) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 5023 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5024 for bucket 6
# Getting block 7 of 8
#   Reserving size (6015) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 2026 for bucket 7
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 2027 for bucket 7
# Getting block 8 of 8
#   Reserving size (6015) for bucket 8
#   Calculating Z arrays for bucket 8
#   Entering block accumulator loop for bucket 8:
#   bucket 8: 10%
#   bucket 8: 20%
#   bucket 8: 30%
#   bucket 8: 40%
#   bucket 8: 50%
#   bucket 8: 60%
#   bucket 8: 70%
#   bucket 8: 80%
#   bucket 8: 90%
#   bucket 8: 100%
#   Sorting block of length 4706 for bucket 8
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 4707 for bucket 8
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 8251
# fchr[G]: 15465
# fchr[T]: 25579
# fchr[$]: 32083
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 4205817 bytes to primary EBWT file: ./1_reference/rRNA_index/NC_000913.3.1.bt2
# Wrote 8028 bytes to secondary EBWT file: ./1_reference/rRNA_index/NC_000913.3.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 32083
#     bwtLen: 32084
#     sz: 8021
#     bwtSz: 8021
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 2006
#     offsSz: 8024
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 168
#     numLines: 168
#     ebwtTotLen: 10752
#     ebwtTotSz: 10752
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 00:00:01
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
#   Time to reverse reference sequence: 00:00:00
# bmax according to bmaxDivN setting: 8020
# Using parameters --bmax 6015 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 6015 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:00
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 7; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 1; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 5346.33 (target: 6014)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 6
#   Reserving size (6015) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
#   bucket 1: 20%
#   bucket 1: 30%
#   bucket 1: 40%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 5197 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5198 for bucket 1
# Getting block 2 of 6
#   Reserving size (6015) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 5158 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5159 for bucket 2
# Getting block 3 of 6
#   Reserving size (6015) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 4893 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 4894 for bucket 3
# Getting block 4 of 6
#   Reserving size (6015) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 5751 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5752 for bucket 4
# Getting block 5 of 6
#   Reserving size (6015) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 5975 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5976 for bucket 5
# Getting block 6 of 6
#   Reserving size (6015) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 5104 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 5105 for bucket 6
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 8251
# fchr[G]: 15465
# fchr[T]: 25579
# fchr[$]: 32083
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 4205817 bytes to primary EBWT file: ./1_reference/rRNA_index/NC_000913.3.rev.1.bt2
# Wrote 8028 bytes to secondary EBWT file: ./1_reference/rRNA_index/NC_000913.3.rev.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 32083
#     bwtLen: 32084
#     sz: 8021
#     bwtSz: 8021
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 2006
#     offsSz: 8024
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 168
#     numLines: 168
#     ebwtTotLen: 10752
#     ebwtTotSz: 10752
#     color: 0
#     reverse: 1
# Total time for backward call to driver() for mirror index: 00:00:00
# mini_RNA-seq_Ecoli_mid-37-1 processing ...
# 	 Aligning to rRNA sequences of reference genome...
# 239373 reads; of these:
#   239373 (100.00%) were paired; of these:
#     227950 (95.23%) aligned concordantly 0 times
#     10 (0.00%) aligned concordantly exactly 1 time
#     11413 (4.77%) aligned concordantly >1 times
#     ----
#     227950 pairs aligned concordantly 0 times; of these:
#       0 (0.00%) aligned discordantly 1 time
#     ----
#     227950 pairs aligned 0 times concordantly or discordantly; of these:
#       455900 mates make up the pairs; of these:
#         455476 (99.91%) aligned 0 times
#         4 (0.00%) aligned exactly 1 time
#         420 (0.09%) aligned >1 times
# 4.86% overall alignment rate
# mini_RNA-seq_Ecoli_mid-37-2 processing ...
# 	 Aligning to rRNA sequences of reference genome...
# 244833 reads; of these:
#   244833 (100.00%) were paired; of these:
#     232210 (94.84%) aligned concordantly 0 times
#     7 (0.00%) aligned concordantly exactly 1 time
#     12616 (5.15%) aligned concordantly >1 times
#     ----
#     232210 pairs aligned concordantly 0 times; of these:
#       0 (0.00%) aligned discordantly 1 time
#     ----
#     232210 pairs aligned 0 times concordantly or discordantly; of these:
#       464420 mates make up the pairs; of these:
#         463872 (99.88%) aligned 0 times
#         5 (0.00%) aligned exactly 1 time
#         543 (0.12%) aligned >1 times
# 5.27% overall alignment rate
# mini_RNA-seq_Ecoli_del_rpoS_mid-37-1 processing ...
# 	 Aligning to rRNA sequences of reference genome...
# 284663 reads; of these:
#   284663 (100.00%) were paired; of these:
#     263701 (92.64%) aligned concordantly 0 times
#     10 (0.00%) aligned concordantly exactly 1 time
#     20952 (7.36%) aligned concordantly >1 times
#     ----
#     263701 pairs aligned concordantly 0 times; of these:
#       0 (0.00%) aligned discordantly 1 time
#     ----
#     263701 pairs aligned 0 times concordantly or discordantly; of these:
#       527402 mates make up the pairs; of these:
#         526737 (99.87%) aligned 0 times
#         6 (0.00%) aligned exactly 1 time
#         659 (0.12%) aligned >1 times
# 7.48% overall alignment rate
# mini_RNA-seq_Ecoli_del_rpoS_mid-37-2 processing ...
# 	 Aligning to rRNA sequences of reference genome...
# 346838 reads; of these:
#   346838 (100.00%) were paired; of these:
#     327715 (94.49%) aligned concordantly 0 times
#     7 (0.00%) aligned concordantly exactly 1 time
#     19116 (5.51%) aligned concordantly >1 times
#     ----
#     327715 pairs aligned concordantly 0 times; of these:
#       0 (0.00%) aligned discordantly 1 time
#     ----
#     327715 pairs aligned 0 times concordantly or discordantly; of these:
#       655430 mates make up the pairs; of these:
#         654771 (99.90%) aligned 0 times
#         8 (0.00%) aligned exactly 1 time
#         651 (0.10%) aligned >1 times
# 5.61% overall alignment rate
# Step 4 is done.

# %% [markdown]
# ## Step 5. Align the RNA-seq reads to reference genome sequence
#
# Align the rRNA-removed sequencing reads from step 3 to reference genome using Bowtie 2, with a maximum insert size of 1000 bp, allowing 1 mismatch after trimming 3 bp at 3' ends.

# %%
# Build the bowtie2 index set of reference genome
dir_genome_ref = f'./1_reference/reference_genome_index/{Organism}'
# !bowtie2-build $dir_genome_fasta $dir_genome_ref

for file in Sample_name_list:
    print(f'{file} processing ...')

    rRNA_del_R1_fastq_gz = f'./2_alignment/rRNA_del_fastq/rRNA_del_{file}.fastq.1.gz'
    rRNA_del_R2_fastq_gz = f'./2_alignment/rRNA_del_fastq/rRNA_del_{file}.fastq.2.gz'
    re_rRNA_del_R1_fastq_gz = f'./2_alignment/rRNA_del_fastq/rRNA_del_{file}_R1.fastq.gz'
    re_rRNA_del_R2_fastq_gz = f'./2_alignment/rRNA_del_fastq/rRNA_del_{file}_R2.fastq.gz'

    os.rename(rRNA_del_R1_fastq_gz,re_rRNA_del_R1_fastq_gz)
    os.rename(rRNA_del_R2_fastq_gz,re_rRNA_del_R2_fastq_gz)

    # !gunzip -k $re_rRNA_del_R1_fastq_gz > /dev/null
    # !gunzip -k $re_rRNA_del_R2_fastq_gz > /dev/null

    R1_file = re_rRNA_del_R1_fastq_gz.split(".gz")[0]
    R2_file = re_rRNA_del_R2_fastq_gz.split(".gz")[0]

    genome_mapped_sam = f'./2_alignment/genome_mapped_{file}.sam'

    print('\t Aligning to reference genome...')
    # !bowtie2 -x $dir_genome_ref -1 $R1_file -2 $R2_file -S $genome_mapped_sam -X 1000 -N 1 -3 3

print('Step 5 is done.')
# Out:
# Settings:
#   Output files: "./1_reference/reference_genome_index/NC_000913.3.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   ./1_reference/NC_000913.3.fasta
# Building a SMALL index
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
# bmax according to bmaxDivN setting: 1160413
# Using parameters --bmax 870310 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 870310 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:00
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 6; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 663092 (target: 870309)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 7
#   Reserving size (870310) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
#   bucket 1: 20%
#   bucket 1: 30%
#   bucket 1: 40%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 415161 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 415162 for bucket 1
# Getting block 2 of 7
#   Reserving size (870310) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 704345 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 704346 for bucket 2
# Getting block 3 of 7
#   Reserving size (870310) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 715232 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 715233 for bucket 3
# Getting block 4 of 7
#   Reserving size (870310) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 638686 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 638687 for bucket 4
# Getting block 5 of 7
#   Reserving size (870310) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 779115 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 779116 for bucket 5
# Getting block 6 of 7
#   Reserving size (870310) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 548871 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 548872 for bucket 6
# Getting block 7 of 7
#   Reserving size (870310) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 840236 for bucket 7
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 840237 for bucket 7
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 1142742
# fchr[G]: 2322833
# fchr[T]: 3500270
# fchr[$]: 4641652
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 5741800 bytes to primary EBWT file: ./1_reference/reference_genome_index/NC_000913.3.1.bt2
# Wrote 1160420 bytes to secondary EBWT file: ./1_reference/reference_genome_index/NC_000913.3.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 4641652
#     bwtLen: 4641653
#     sz: 1160413
#     bwtSz: 1160414
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 290104
#     offsSz: 1160416
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 24176
#     numLines: 24176
#     ebwtTotLen: 1547264
#     ebwtTotSz: 1547264
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 00:00:03
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
#   Time to reverse reference sequence: 00:00:00
# bmax according to bmaxDivN setting: 1160413
# Using parameters --bmax 870310 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 870310 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:00
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 2, merged 7; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 1; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 580206 (target: 870309)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 8
#   Reserving size (870310) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
#   bucket 1: 20%
#   bucket 1: 30%
#   bucket 1: 40%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 696384 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 696385 for bucket 1
# Getting block 2 of 8
#   Reserving size (870310) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 333881 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 333882 for bucket 2
# Getting block 3 of 8
#   Reserving size (870310) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 565798 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 565799 for bucket 3
# Getting block 4 of 8
#   Reserving size (870310) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 312583 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 312584 for bucket 4
# Getting block 5 of 8
#   Reserving size (870310) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 783371 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 783372 for bucket 5
# Getting block 6 of 8
#   Reserving size (870310) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 823242 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 823243 for bucket 6
# Getting block 7 of 8
#   Reserving size (870310) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 609090 for bucket 7
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 609091 for bucket 7
# Getting block 8 of 8
#   Reserving size (870310) for bucket 8
#   Calculating Z arrays for bucket 8
#   Entering block accumulator loop for bucket 8:
#   bucket 8: 10%
#   bucket 8: 20%
#   bucket 8: 30%
#   bucket 8: 40%
#   bucket 8: 50%
#   bucket 8: 60%
#   bucket 8: 70%
#   bucket 8: 80%
#   bucket 8: 90%
#   bucket 8: 100%
#   Sorting block of length 517296 for bucket 8
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 517297 for bucket 8
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 1142742
# fchr[G]: 2322833
# fchr[T]: 3500270
# fchr[$]: 4641652
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 5741800 bytes to primary EBWT file: ./1_reference/reference_genome_index/NC_000913.3.rev.1.bt2
# Wrote 1160420 bytes to secondary EBWT file: ./1_reference/reference_genome_index/NC_000913.3.rev.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 4641652
#     bwtLen: 4641653
#     sz: 1160413
#     bwtSz: 1160414
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 290104
#     offsSz: 1160416
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 24176
#     numLines: 24176
#     ebwtTotLen: 1547264
#     ebwtTotSz: 1547264
#     color: 0
#     reverse: 1
# Total time for backward call to driver() for mirror index: 00:00:04
# mini_RNA-seq_Ecoli_mid-37-1 processing ...
# 	 Aligning to reference genome...
# 227950 reads; of these:
#   227950 (100.00%) were paired; of these:
#     6132 (2.69%) aligned concordantly 0 times
#     214503 (94.10%) aligned concordantly exactly 1 time
#     7315 (3.21%) aligned concordantly >1 times
#     ----
#     6132 pairs aligned concordantly 0 times; of these:
#       236 (3.85%) aligned discordantly 1 time
#     ----
#     5896 pairs aligned 0 times concordantly or discordantly; of these:
#       11792 mates make up the pairs; of these:
#         9704 (82.29%) aligned 0 times
#         1819 (15.43%) aligned exactly 1 time
#         269 (2.28%) aligned >1 times
# 97.87% overall alignment rate
# mini_RNA-seq_Ecoli_mid-37-2 processing ...
# 	 Aligning to reference genome...
# 232210 reads; of these:
#   232210 (100.00%) were paired; of these:
#     3751 (1.62%) aligned concordantly 0 times
#     220960 (95.16%) aligned concordantly exactly 1 time
#     7499 (3.23%) aligned concordantly >1 times
#     ----
#     3751 pairs aligned concordantly 0 times; of these:
#       320 (8.53%) aligned discordantly 1 time
#     ----
#     3431 pairs aligned 0 times concordantly or discordantly; of these:
#       6862 mates make up the pairs; of these:
#         4853 (70.72%) aligned 0 times
#         1752 (25.53%) aligned exactly 1 time
#         257 (3.75%) aligned >1 times
# 98.96% overall alignment rate
# mini_RNA-seq_Ecoli_del_rpoS_mid-37-1 processing ...
# 	 Aligning to reference genome...
# 263701 reads; of these:
#   263701 (100.00%) were paired; of these:
#     5623 (2.13%) aligned concordantly 0 times
#     249198 (94.50%) aligned concordantly exactly 1 time
#     8880 (3.37%) aligned concordantly >1 times
#     ----
#     5623 pairs aligned concordantly 0 times; of these:
#       359 (6.38%) aligned discordantly 1 time
#     ----
#     5264 pairs aligned 0 times concordantly or discordantly; of these:
#       10528 mates make up the pairs; of these:
#         7648 (72.64%) aligned 0 times
#         2447 (23.24%) aligned exactly 1 time
#         433 (4.11%) aligned >1 times
# 98.55% overall alignment rate
# mini_RNA-seq_Ecoli_del_rpoS_mid-37-2 processing ...
# 	 Aligning to reference genome...
# 327715 reads; of these:
#   327715 (100.00%) were paired; of these:
#     5914 (1.80%) aligned concordantly 0 times
#     310906 (94.87%) aligned concordantly exactly 1 time
#     10895 (3.32%) aligned concordantly >1 times
#     ----
#     5914 pairs aligned concordantly 0 times; of these:
#       495 (8.37%) aligned discordantly 1 time
#     ----
#     5419 pairs aligned 0 times concordantly or discordantly; of these:
#       10838 mates make up the pairs; of these:
#         7690 (70.95%) aligned 0 times
#         2727 (25.16%) aligned exactly 1 time
#         421 (3.88%) aligned >1 times
# 98.83% overall alignment rate
# Step 5 is done.

# %% [markdown]
# ## Step 6. Convert the SAM files generated from Bowtie 2 into BAM, GFF, and Bedgraph files
#
# Convert the SAM files generated from Bowtie 2 into BAM using Samtools and generate GFF files for downstream analysis.

# %%
for file in Sample_name_list:
    print(f'{file} processing ...')
    sam_bam_unsorted = f'./2_alignment/{file}.unsorted.bam'
    sam_bam_sorted = f'./2_alignment/{file}.bam'
    genome_mapped_sam = f'./2_alignment/genome_mapped_{file}.sam'

    # !samtools view -bS $genome_mapped_sam -o $sam_bam_unsorted
    # !samtools sort $sam_bam_unsorted -o $sam_bam_sorted
    # !rm $sam_bam_unsorted
    # !samtools index $sam_bam_sorted

    print("\t Samtools running is done.")

    dir_gff_output = f'./3_result/{file}.gff'
    convert_samfile_to_gff( genome_mapped_sam, dir_gff_output )
    print("\t Making the gff file is done.")

    dir_bed_output = f'./3_result/{file}'
    convert_sam_to_bedgraph(genome_mapped_sam, dir_bed_output)
    print('\t Making the bedGrpah file is done.\n')

print('Step 6 is done.')
# Out:
# mini_RNA-seq_Ecoli_mid-37-1 processing ...
# 	 Samtools running is done.
# 	 Making the gff file is done.
# 	 Making the bedGrpah file is done.
#
# mini_RNA-seq_Ecoli_mid-37-2 processing ...
# 	 Samtools running is done.
# 	 Making the gff file is done.
# 	 Making the bedGrpah file is done.
#
# mini_RNA-seq_Ecoli_del_rpoS_mid-37-1 processing ...
# 	 Samtools running is done.
# 	 Making the gff file is done.
# 	 Making the bedGrpah file is done.
#
# mini_RNA-seq_Ecoli_del_rpoS_mid-37-2 processing ...
# 	 Samtools running is done.
# 	 Making the gff file is done.
# 	 Making the bedGrpah file is done.
#
# Step 6 is done.
